# %% [markdown]
# # 🛳️ Titanic Data Investigation
#
# **Scenario:**
# You’ve been hired to prepare clean Titanic passenger data for a museum exhibit. The original data comes from multiple sources. Your mission is to:
#
# Your mission is to:
# 1. Reshape a messy summary sheet into tidy format
# 2. Inspect the Titanic dataset
# 3. Combine data for richer analysis
# 4. Detect and fix missing information
# 5. Transform and normalize values
# 6. Create one clear visualization for the exhibit
#
# each step has a **Checkpoint** with assertions to verify the solution.
#
#
# if you need help with pandas syntax check out [this](https://pandas.pydata.org/docs/reference/frame.html) out

# %% [markdown]
# ## 0. Setup & Reproducibility
# Please run the following cells to set up the environment and import necessary libraries.

# %%
# !pip install pandas==2.2.2 seaborn==0.13.2 numpy==2.0.2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.__version__, np.__version__, sns.__version__

# %%
def load_titanic():
    try:
        return sns.load_dataset("titanic")
    except Exception:
        path = "data/titanic.csv"
        return pd.read_csv(path)

df_full = load_titanic()
df = df_full.iloc[:-100].copy()
new_data = sns.load_dataset("titanic").tail(100)

summary_sheet = (
    df.groupby(["class", "sex", "embarked"], observed=True)["survived"]
      .mean()
      .round(3)
      .reset_index()
      .pivot(index=["class", "sex"], columns="embarked", values="survived")
      .reset_index()
)

class_info = pd.DataFrame({
    "class": ["First", "Second", "Third"],
    "class_description": [
        "luxury cabins and dining",
        "comfortable standard cabins",
        "basic accommodation and shared rooms"
    ],
    "price_category": ["high", "mid", "low"]
})

# %% [markdown]
# ## 1) Reshape
#
# You received a summary sheet from the museum team. It shows passenger survival rates.
#
# **Given:**
# - A DataFrame called `summary_sheet`
#
#
# **Do this:**
# 1. Preview the provided wide table (`summary_sheet`).
# 2. Convert this wide table back to tidy format, where each row is one observation.
#
# For the reshape exercise, please modify the provided `summary_sheet` DataFrame in place.

# %%
#TODO RESHAPE
# Out:
#     class     sex embarked  survival_rate
# 0   First  female        C          0.974
# 1   First    male        C          0.385
# 2  Second  female        C          1.000
# 3  Second    male        C          0.125
# 4   Third  female        C          0.632

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# - Columns: `class`, `sex`, `C`, `Q`, `S` → representing embarkation ports
# - Each cell shows the **average survival rate** for that group
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# - melt() takes columns and turns them into rows.
# - Use:
# ```python
# summary_sheet = summary_sheet.melt(
#     id_vars=["class", "sex"],
#     var_name="embarked",
#     value_name="survival_rate"
# )
# ```
# </details>

# %% [markdown]
# ### Checkpoint 1

# %%
assert set(("C", "Q", "S")).isdisjoint(set(summary_sheet.columns))
print("✅ Done")
# Out:
# ✅ Done

# %% [markdown]
# ## 2) Inspect
#
# The archives team has discovered a row-level Titanic passenger dataset.
#
# **Goal:** Inspect this newly discovered source (`df`) to understand its shape, types, and missingness.
#
# **Do this:**
# 1. Inspect `df`
# 2. Count missing values per column
# 3. Identify 3–4 candidate columns to clean

# %%
#TODO INSPECT
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 791 entries, 0 to 790
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     791 non-null    int64
#  1   pclass       791 non-null    int64
#  2   sex          791 non-null    object
#  3   age          630 non-null    float64
#  4   sibsp        791 non-null    int64
#  5   parch        791 non-null    int64
#  6   fare         791 non-null    float64
#  7   embarked     790 non-null    object
#  8   class        791 non-null    category
#  9   who          791 non-null    object
#  10  adult_male   791 non-null    bool
#  11  deck         183 non-null    category
#  12  embark_town  790 non-null    object
#  13  alive        791 non-null    object
#  14  alone        791 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 71.7+ KB
# deck           608
# age            161
# embarked         1
# embark_town      1
# survived         0
# pclass           0
# sex              0
# sibsp            0
# parch            0
# fare             0
# dtype: int64

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# - Use `df.info()` to see dtypes and non-null counts
# - Use `df.isna().sum()` to count missing values
# - Typical targets here: `deck`, `age`, `embarked` and `embark_town`
# </details>

# %% [markdown]
# ### Checkpoint 2

# %%
expected = {"survived","pclass","sex","age","sibsp","parch","fare","embarked","class","who","adult_male","deck","embark_town","alive"}
assert expected.issubset(set(df.columns))
print("✅ Done")

# %% [markdown]
# ## 3) Combine
#
# The museum’s data team discovered new passenger data and prepared class descriptions to enrich your dataset.
#
# **Given:**
# - newly discovered data of another 100 passengers: `new_data`
# - A prepared lookup table: `class_info`
#
# **Do this:**
# 1. **Append** the enriched `new_data` to `df` and verify the result at Checkpoint 3.1
# 2. Inspect and merge **`class_description`** from `class_info` into `df` and verify the result at Checkpoint 3.2

# %%
# 1) TODO APPEND

# %% [markdown]
# <details>
# <summary>💡 Hint (Concat)</summary>
#
# - Use `pd.concat([df, new_rows], axis=0, ignore_index=True)` to append rows.
# - `ignore_index=True` re-numbers the index 0..N-1.
# </details>

# %% [markdown]
# ### Checkpoint 3.1

# %%
assert len(df) == 891
print("✅ Done")
prev_len = len(df)

# %% [markdown]
# #### Merge prepared information
#
# Now the data team gives you an additional **lookup table** named `class_info` that maps the Titanic’s passenger classes
# (`First`, `Second`, `Third`) to **descriptive text** and **price category**.

# %%
#TODO MERGE
# Out:
#    class     sex     fare                     class_description price_category
# 0  Third    male   7.2500  basic accommodation and shared rooms            low
# 1  First  female  71.2833              luxury cabins and dining           high
# 2  Third  female   7.9250  basic accommodation and shared rooms            low
# 3  First  female  53.1000              luxury cabins and dining           high
# 4  Third    male   8.0500  basic accommodation and shared rooms            low

# %% [markdown]
# <details>
# <summary>💡 Hint (Merge)</summary>
#
# - Think of `merge()` as connecting tables **by a shared key** (here: <code>'class'</code>).
# - Your **join keys must match in both *name* and *dtype*** on both sides.
# - `how='left'` so every passenger row is kept, even if the key isn't in the lookup.
# - Use <code>validate="m:1"</code> to ensure many-to-one (many passengers → one label per band).
# </details>

# %% [markdown]
# ### Checkpoint 3.2

# %%
assert len(df) == prev_len, "❌ Row count changed, check merge keys."

missing_desc = df["class_description"].isna().sum()
assert missing_desc == 0
print("✅ Done")

# %% [markdown]
# ## 4) Find & Fill Missing Data
#
# **Goal:**
# After combining the new arrivals and enriching information, audit the dataset for gaps and make values consistent so downstream analysis and visuals are reliable.
#
# **Do this:**
# 1. Fill missing `age` with the **median**
# 2. Fill missing `embarked` & `embark_town` with the most **common** values of the column
# 3. Replace missing `deck` with "Unknown"
# 4. Re-check missingness

# %%
#TODO FILL MISSING
# Out:
# survived             0
# who                  0
# class_description    0
# alone                0
# alive                0
# embark_town          0
# deck                 0
# adult_male           0
# dtype: int64

# %% [markdown]
# <details>
# <summary>💡 Why median/mode?</summary>
#
# - **Age (numeric):** median is robust to outliers
# - **Embarked (categorical):** mode reflects the most common category
# - **Deck (string):** "Unknown" preserves the fact that a value should exist but wasn’t recorded
# </details>

# %% [markdown]
# <details>
# <summary>💡 Error when trying to fill deck?</summary>
#
# The `deck` column is stored as a *Categorical dtype* in pandas.
# To fill missing values with a new label (`"Unknown"`), you must first **add it to the category list**:
# ```python
# df["deck"] = df["deck"].cat.add_categories("Unknown")
# ```
#
# Alternatively, you can convert deck to string before filling if you don’t need the categorical type:
# ```python
# df["deck"] = df["deck"].astype("string")
# ```
# </details>

# %% [markdown]
# ### Checkpoint 2

# %%
assert df["age"].isna().sum() == 0
assert df["embarked"].isna().sum() == 0
assert df["deck"].isna().sum() == 0
print("✅ Done")

# %% [markdown]
# ## 5) Transform & Normalize
#
# **Goal:**
# We will create new features and scale numerical values for better comparison and visualization. This will improve interpretability and prepare numerical columns for analysis.
#
# **Given:**
# - A cleaned `df` (after handling missing values).
# - Columns such as `fare`, `age`, `sex`, and `embarked`.
#
# **Do this:**
# 1. Create a **log-transformed** version of `fare` to reduce skew.
# 2. Apply **min–max normalization** to `age` and `fare` to bring them to a 0–1 scale.

# %%
#TODO TRANSFORM & NORMALIZE
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male     deck  embark_town alive  alone  \
# 0    man        True  Unknown  Southampton    no  False
# 1  woman       False        C    Cherbourg   yes  False
# 2  woman       False  Unknown  Southampton   yes   True
# 3  woman       False        C  Southampton   yes  False
# 4    man        True  Unknown  Southampton    no   True
#
#                       class_description price_category  log_fare  age_norm  \
# 0  basic accommodation and shared rooms            low  2.110213  0.271174
# 1              luxury cabins and dining           high  4.280593  0.472229
# 2  basic accommodation and shared rooms            low  2.188856  0.321438
# 3              luxury cabins and dining           high  3.990834  0.434531
# 4  basic accommodation and shared rooms            low  2.202765  0.434531
#
#    fare_norm
# 0   0.014151
# 1   0.139136
# 2   0.015469
# 3   0.103644
# 4   0.015713

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# - Use `np.log1p()` for a safe logarithmic transformation (it handles zeros).
# - Normalization rescales values between 0 and 1:
#   x = (x - min(x)) / (max(x) - min(x))
# </details>

# %%
assert "log_fare" in df.columns
assert "fare_norm" in df.columns and 0 <= df["fare_norm"].min() <= 1
assert df["log_fare"].isna().sum() == 0 or df["log_fare"].notna().sum() > 0

print("✅ Done")
# Out:
# ✅ Done

# %% [markdown]
# ## 6) Visualize
#
# **Goal:**
# Explore insights from the tidy and transformed dataset through simple visualizations.
#
# **Given:**
# - A tidy `df` with transformations and normalized numeric columns.
#
# **Do this:**
# 1. Compare `fare` distributions before and after log transformation.
# 2. Examine survival rates by sex and passenger class.

# %%
#TODO VISUALIZE

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# - `sns.histplot()` is useful to visualize distribution shape and skew.
# - `sns.barplot()` shows mean values (by default) and supports grouping via `hue`.
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# a feasible solution would be:
# ```python
# # 1)
# fig, axes = plt.subplots(1, 2, figsize=(12, 4))
# sns.histplot(df["fare"], ax=axes[0], kde=True)
# axes[0].set_title("Original Fare Distribution")
# sns.histplot(df["log_fare"], ax=axes[1], kde=True)
# axes[1].set_title("Log-Transformed Fare Distribution")
# plt.tight_layout()
# plt.show()
#
# # 2)
# plt.figure(figsize=(6, 4))
# sns.barplot(data=df, x="sex", y="survived", hue="class")
# plt.title("Survival Rate by Sex and Class")
# plt.show()
# ```
# </details>

# %% [markdown]
# ## 7) Wrap-Up
#
# **Goal:**
# Summarize what we learned and confirm that our dataset is now *tidy, clean, and analysis-ready.*
# Reflect on how each wrangling step contributed to turning raw Titanic data into structured insight.
#
# **Recap:**
# 1. **Inspected** the newly discovered row-level dataset (initially missing the last 100 rows).
# 2. **Reshaped** a separate wide summary sheet into tidy form and **handed it off to the visualization team**; the tutorial then continued with the row-level dataset (`df`).
# 3. **Combined** data (appended the missing last 100 rows and merged lookup info) to enrich insights.
# 4. **Handled Missing Data** to make gaps explicit and consistent.
# 5. **Transformed & Normalized** numeric values for interpretability.
# 6. **Visualized** tidy data to discover patterns and confirm transformations.
